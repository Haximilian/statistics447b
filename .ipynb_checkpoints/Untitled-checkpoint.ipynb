# %%
library(ggmap)
training <- read.csv("data/train.csv")
# Out:
# Loading required package: ggplot2
#
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
#
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Error in `[.data.frame`(data, , deparse(substitute(x))): undefined columns selected
# Traceback:
#
# 1. qmplot(mean(training$Longitude), mean(training$Latitude), data = training)
# 2. make_bbox(lon = data[, deparse(substitute(x))], lat = data[,
#  .     deparse(substitute(y))], f = f)
# 3. extendrange(range(lon, na.rm = TRUE), f = f)
# 4. data[, deparse(substitute(x))]
# 5. `[.data.frame`(data, , deparse(substitute(x)))
# 6. stop("undefined columns selected")
