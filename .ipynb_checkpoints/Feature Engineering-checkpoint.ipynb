# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
DatasetPath <- "./train.csv"
training <- read.csv(DatasetPath)

# %%
head(training)
# Out:
#   RowId   IntersectionId Latitude Longitude EntryStreetName
# 1 1921357 0              33.79166 -84.43003 Marietta Boulevard Northwest
# 2 1921358 0              33.79166 -84.43003 Marietta Boulevard Northwest
# 3 1921359 0              33.79166 -84.43003 Marietta Boulevard Northwest
# 4 1921360 0              33.79166 -84.43003 Marietta Boulevard Northwest
# 5 1921361 0              33.79166 -84.43003 Marietta Boulevard Northwest
# 6 1921362 0              33.79166 -84.43003 Marietta Boulevard Northwest
#   ExitStreetName               EntryHeading ExitHeading Hour Weekend ⋯
# 1 Marietta Boulevard Northwest NW           NW          0    0       ⋯
# 2 Marietta Boulevard Northwest SE           SE          0    0       ⋯
# 3 Marietta Boulevard Northwest NW           NW          1    0       ⋯
# 4 Marietta Boulevard Northwest SE           SE          1    0       ⋯
# 5 Marietta Boulevard Northwest NW           NW          2    0       ⋯
# 6 Marietta Boulevard Northwest SE           SE          2    0       ⋯
#   TimeFromFirstStop_p40 TimeFromFirstStop_p50 TimeFromFirstStop_p60
# 1 0                     0                     0
# 2 0                     0                     0
# 3 0                     0                     0
# 4 0                     0                     0
# 5 0                     0                     0
# 6 0                     0                     0
#   TimeFromFirstStop_p80 DistanceToFirstStop_p20 DistanceToFirstStop_p40
# 1 0                     0                       0
# 2 0                     0                       0
# 3 0                     0                       0
# 4 0                     0                       0
# 5 0                     0                       0
# 6 0                     0                       0
#   DistanceToFirstStop_p50 DistanceToFirstStop_p60 DistanceToFirstStop_p80
# 1 0                       0                       0
# 2 0                       0                       0
# 3 0                       0                       0
# 4 0                       0                       0
# 5 0                       0                       0
# 6 0                       0                       0
#   City
# 1 Atlanta
# 2 Atlanta
# 3 Atlanta
# 4 Atlanta
# 5 Atlanta
# 6 Atlanta

# %%
augmentRightTurn <- function(dataset) {
    isRightTurn <- function(entry, exit) {
        rightexit <- list(
            N = c("NW", "W", "SW"),
            NW = c("W", "SW", "S"),
            W = c("SW", "S", "SE"),
            SW = c("S", "SE", "E"),
            S = c("SE", "E", "NE"),
            SE = c("E", "NE", "N"),
            E = c("NE", "N", "NW"),
            NE = c("N", "NW", "W")
        )
        exit %in% rightexit[[entry]]
    }
    vIsRightTurn <- Vectorize(isRightTurn)
    dataset %>% 
        mutate(RightTurn = vIsRightTurn(EntryHeading, ExitHeading)) %>%
        group_by(IntersectionId, EntryHeading) %>%
        summarize(RightTurnAllowed = max(RightTurn)) %>%
        inner_join(dataset)
}

# %%
augmented <- augmentRightTurn(training)
# Out:
# `summarise()` regrouping output by 'IntersectionId' (override with `.groups` argument)
#
# Joining, by = c("IntersectionId", "EntryHeading")

# %%
t <- augmented %>% filter(TotalTimeStopped_p50 > 0)
boxplot(log(t$TotalTimeStopped_p50) ~ t$RightTurnAllowed)
# Out:
# plot without title

# %%
augmentLeftTurn <- function(dataset) {
    isLeftTurn <- function(entry, exit) {
        leftexit <- list(
            N = c("NE", "E", "SE"),
            NW = c("N", "NE", "E"),
            W = c("NW", "N", "NE"),
            SW = c("W", "NW", "N"),
            S = c("SW", "W", "NW"),
            SE = c("S", "SW", "W"),
            E = c("SE", "S", "SW"),
            NE = c("E", "SE", "S")
        )
        exit %in% leftexit[[entry]]
    }
    vIsLeftTurn <- Vectorize(isLeftTurn)
    dataset %>% 
        mutate(LeftTurn = vIsLeftTurn(EntryHeading, ExitHeading)) %>%
        group_by(IntersectionId, EntryHeading) %>%
        summarize(LeftTurnAllowed = max(LeftTurn)) %>%
        inner_join(dataset)
}

# %%
augmented <- augmentLeftTurn(training)
# Out:
# `summarise()` regrouping output by 'IntersectionId' (override with `.groups` argument)
#
# Joining, by = c("IntersectionId", "EntryHeading")

# %%
t <- augmented %>% filter(TotalTimeStopped_p50 > 0)
boxplot(log(t$TotalTimeStopped_p50) ~ t$LeftTurnAllowed)
# Out:
# plot without title

# %%
augmented <- augmented %>% mutate(straightThrough = EntryHeading == ExitHeading)

# %%
t <- augmented %>% filter(TotalTimeStopped_p50 > 0)
boxplot(log(t$TotalTimeStopped_p50) ~ t$straightThrough)
# Out:
# plot without title
